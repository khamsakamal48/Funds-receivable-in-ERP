# %% [markdown]
# ## Load Libraries

# %%
import pandas as pd
# import modin.pandas as pd
from dotenv import load_dotenv
import os
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# %% [markdown]
# ## Load Environment variables

# %%
# Load the .env file
load_dotenv()

# Fetch environment variables
db_address = os.getenv('DB_ADDRESS')
db_port = os.getenv('DB_PORT')
db_username = os.getenv('DB_USERNAME')
db_password = quote_plus(os.getenv('DB_PASSWORD'))
db_name = os.getenv('DB')

# %% [markdown]
# ## Functions

# %%
def get_db_connection():
    """
    Establishes a connection to the PostgreSQL database using SQLAlchemy.
    - The `postgresql+psycopg2` dialect indicates that we're using PostgreSQL as the database backend.
    - The `{DB_USER}:{DB_PASS}` part specifies the username and password to use for connections.
    - The `@{DB_IP}:{DB_PORT}` part specifies the hostname and port number to use when connecting to the database.
    - The `/`${DB}` part specifies the database name or schema to connect to.

    :return: engine.connect(): An active connection object to the PostgreSQL database.
    """
    engine = create_engine(f'postgresql://{db_username}:{db_password}@{db_address}:{db_port}/{db_name}')

    # Establish a connection to the database:
    #   - This returns an active connection object, which can be used to execute queries and interact with the database.
    return engine.connect()

def fetch_data_from_sql(query):
    """
    Fetches data from a SQL table and returns it as a pandas DataFrame.

    :param query: (str) The SQL query to execute on the database.
    :return: pd.DataFrame: A pandas DataFrame containing the results of the SQL query.
    """

    # Establish a connection to the PostgreSQL database using get_db_connection():
    conn = get_db_connection()

    # Execute the SQL query on the database and store the result in a pandas DataFrame:
    df = pd.read_sql(query, conn)

    # Close the connection to the database to free up resources:
    conn.close()

    # Return the pandas DataFrame containing the results of the SQL query:
    return df

def change_column_names(column_list, std=True):
    if std:
        return [col.strip().title().replace('_', ' ') for col in column_list]

    else:
        return [col.strip().lower().replace(' ', '_') for col in column_list]

# %% [markdown]
# ## Get Data

# %% [markdown]
# ### Transaction

# %%
query_transaction = '''
    SELECT
        *
    FROM
        erp_data.funds_received.transactions
    '''

transaction = fetch_data_from_sql(query_transaction)

# %% [markdown]
# ### Projects

# %%
 # Get existing master
query_project_dir_old = '''
        SELECT
            *
        FROM
            erp_data.funds_received.project_directory
'''

project_directory = fetch_data_from_sql(query_project_dir_old)

# Standardise column names
project_directory.columns = change_column_names(project_directory.columns)

# %% [markdown]
# ### WBS Data

# %%
query_transaction = '''
        SELECT
            *
        FROM
            erp_data.funds_received.wbs
        '''

wbs = fetch_data_from_sql(query_transaction)

# %% [markdown]
# ### Data Cleaning

# %%
# Remove extra spaces from column names
transaction_col = transaction.columns
transaction_col = [col.strip() for col in transaction_col]
transaction.columns = transaction_col

wbs_col = wbs.columns
wbs_col = [col.strip() for col in wbs_col]
wbs.columns = wbs_col

# %%
if transaction.shape[0] > 0 and wbs.shape[0] > 0 and project_directory.shape[0] > 0:
    # Perform WBS mapping
    transaction = transaction.merge(wbs[['WBS', 'WBS Details']].drop_duplicates(), how='left',
                                    left_on='Project definition', right_on='WBS')

    transaction = transaction.merge(wbs[['Sub WBS', 'SUB WBS Details']].drop_duplicates(), how='left',
                                    left_on='Object', right_on='Sub WBS')

    transaction['Project Id'] = transaction['SUB WBS Details'].apply(
        lambda x: str(x).strip().lower().replace(' ', '_'))

    # Assign Category
    transaction = transaction.merge(project_directory[['Project Id', 'Category']], how='left', on='Project Id').copy()

# %%
start_date = pd.to_datetime('01-04-2024', format='%d-%m-%Y')
end_date = pd.to_datetime('24-12-2024', format='%d-%m-%Y')

# %%
transaction['Ref. document number'] = transaction['Ref. document number'].fillna('').astype(str)

# %%
transaction['Document Number'] = transaction['Document Number'].fillna('').astype(str)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/CloudStorage/OneDrive-Alumni&CorporateRelations,IITBombay/Application Folders/Xcode/Github/Funds-receivable-in-ERP/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Document Number'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 transaction['Document Number'] = transaction['Document Number'].fillna('').astype(str)
#
# File ~/Library/CloudStorage/OneDrive-Alumni&CorporateRelations,IITBombay/Application Folders/Xcode/Github/Funds-receivable-in-ERP/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/Library/CloudStorage/OneDrive-Alumni&CorporateRelations,IITBombay/Application Folders/Xcode/Github/Funds-receivable-in-ERP/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Document Number'

# %% [markdown]
# ### Cleaned Data

# %%
# Final Data
final_data = transaction[(transaction['Document Date'].between(start_date, end_date))]

# %%
final_data_bak = final_data.copy()

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Logic 1

# %% [markdown]
# #### Steps:
# - For Indian Donation
#     - Take all the DR data
#     - Filter by Cost Element ≠ 550510, 550511
#     - For each "Project Definition",
#         - Get the total for each Project Definition
#         - Get the corresponding "Ref. document number". There could be multiple document numbers.
#         - For each document numbers,
#             - Get all the SB entries
#             - Get the total of all SB entries
#         - Get the total of the SB entries and compare it with the total for each Project Definition
#         - If the difference is same as total for each project definition, then use the original project definition as the Sub-WBS code
#         - If the difference is less, then categorise the difference as 'Un-assigned' in the Sub-WBS code
#     - Create a Dataframe of project wise breakup for each "Project Definition"

# %% [raw]
# # Step 1
# dr_data = final_data[
#     (final_data['Document type'] == 'DR') &
#
#     # Step 2
#     ~(final_data['Cost Element'].isin([550510, 550511]))
# ]

# %% [raw]
# dr_data['Val/COArea Crcy'].sum()

# %% [raw]
# dr_data.sample(10)

# %% [raw]
# project_wise_breakup = pd.DataFrame()
#
# for proj in dr_data['Project definition'].unique():
#     # Step 3
#     proj_total_dr = abs(dr_data.loc[dr_data['Project definition'] == proj, 'Val/COArea Crcy'].sum())
#
#     # Step 4
#     ref_nos = final_data.loc[
#         final_data['Project definition'] == proj,
#         'Ref. document number'
#     ]
#
#     # Step 5
#     dr_sb_entries = pd.DataFrame()
#     for ref in ref_nos:
#         df = final_data[
#             (final_data['Ref. document number'] == ref) &
#             (final_data['Document type'] =='SB')
#         ]
#
#         dr_sb_entries = pd.concat([dr_sb_entries, df], ignore_index=True)
#
#     dr_sb_entries = dr_sb_entries.copy()
#
#     # Step 6
#     proj_total_sb = abs(dr_sb_entries['Val/COArea Crcy'].sum())
#
#     # Step 7
#     proj_total_diff = proj_total_dr - proj_total_sb
#
#     # Step 8
#     if proj_total_sb == 0:
#         dr_sb_entries = dr_data[dr_data['Project definition'] == proj]
#         # dr_sb_entries['Val/COArea Crcy'] = dr_sb_entries['Val/COArea Crcy'].apply(abs)
#
#     elif proj_total_diff < proj_total_dr:
#         unassigned = {
#             'Val/COArea Crcy': proj_total_diff,
#             'WBS': 'Unassigned',
#             'WBS Details': 'Unassigned',
#             'Sub WBS': 'Unassigned',
#             'SUB WBS Details': 'Unassigned',
#             'Project Id': 'Unassigned',
#             'Category': 'Unassigned'
#         }
#
#         dr_sb_entries = pd.concat([dr_sb_entries, pd.DataFrame(data=unassigned, index=[0])], axis=0, ignore_index=True)
#
#     elif proj_total_diff > proj_total_dr:
#         print(proj, 'difference is high')
#
#     # Step Last
#     dr_sb_entries.insert(0, 'OG Project', proj)
#     # og_project = pd.DataFrame(data={
#     #     'OG Project': proj
#     # }, index=range(0, dr_sb_entries.shape[0]))
#     #
#     # dr_sb_entries = pd.concat([og_project, dr_sb_entries], axis=1, ignore_index=True)
#
#     project_wise_breakup = pd.concat([project_wise_breakup, dr_sb_entries], ignore_index=True)

# %% [raw]
# project_wise_breakup['Val/COArea Crcy'].sum()

# %% [raw]
# project_wise_breakup

# %% [raw]
# dr_data.loc[dr_data['Project definition'] == proj, 'Val/COArea Crcy'].sum()

# %% [raw]
# dr_data[dr_data['Project definition'] == proj]

# %% [raw]
# dr_sb_entries

# %% [raw]
# final_data.sample(10)

# %% [raw]
# final_data[final_data['SUB WBS Details'].fillna('').str.contains('91')]

# %% [raw]
# data_1 = fetch_data_from_sql('''
# SELECT
#     *
# FROM
#     erp_data.funds_received.transactions
# WHERE
#     "Project definition" LIKE '%%91%%' AND
#     "Document type" = 'SB'
# ''')

# %% [raw]
# data_1

# %% [markdown]
# ### Logic 2
# - For each Projects in Transaction without any filter~ with only DR and SB entries
#     - Pick the SB transaction for that project/wbs code
#     - If there's no SB entry, use the DR entry directly
#     - Perform sub-total and get rid of the records which nullify each other i.e. amount = 0
#         - Of the remaining transactions,
#             - Identify the reference document numbers
#             - Prepare a dataset of these document numbers. All the entries will be SB
#             - Exclude the original project/WBS code
#     - Of the remaining transaction, get their corresponding ref. document numbers
#         - For each document numbers,
#             - Filter all corresponding SB transactions (filtered data with SB entries)
#             - Exclude the original project/wbs code from the filtered dataset
#             - If the value is less than 0, it's transferred to ()
#             - If the value is greater than 0, it's transferred from

# %%
final_data = final_data_bak.copy()

# %%
import pandas as pd
# from itertools import combinations
from collections import defaultdict

# def find_nullifying_groups(df):
#     """
#     Identify groups of values in the 'Value in Obj. Crcy' column that nullify each other,
#     and return their corresponding 'Ref. document number'.
#
#     Args:
#     df (pd.DataFrame): The input DataFrame with columns 'Ref. document number' and 'Value in Obj. Crcy'.
#
#     Returns:
#     pd.DataFrame: A DataFrame containing the 'Ref. document number' and 'Value in Obj. Crcy'
#                   of nullifying groups.
#     """
#     # Initialize a set to store indices of rows that nullify each other
#     nullifying_indices = set()
#
#     # Extract 'Value in Obj. Crcy' and their indices
#     values = df['Value in Obj. Crcy'].tolist()
#     index_map = df.index.tolist()  # Map positional indices to actual DataFrame indices
#
#     n = len(values)
#
#     # Check all combinations of rows to find nullifying groups
#     for r in range(2, n + 1):  # At least 2 elements in the combination
#         for combo in combinations(range(n), r):
#             subset = [values[i] for i in combo]
#             if abs(sum(subset)) < 1e-9:  # Check for near-zero sum
#                 # Map positional indices to DataFrame indices
#                 nullifying_indices.update(index_map[i] for i in combo)
#
#     # Convert the set of indices to a list and filter the DataFrame
#     result = df.loc[list(nullifying_indices)]
#     return result

def find_nullifying_groups(df):
    """
    Efficiently find and return rows where values in 'Value in Obj. Crcy' nullify each other.

    Args:
    df (pd.DataFrame): The input DataFrame with columns 'Ref. document number' and 'Value in Obj. Crcy'.

    Returns:
    pd.DataFrame: A DataFrame containing the 'Ref. document number' and 'Value in Obj. Crcy'
                  of nullifying groups.
    """
    # Sort values by absolute amount in descending order (higher values first)
    df = df.reindex(df['Val/COArea Crcy'].abs().sort_values(ascending=False).index)

    # Dictionary to store unmatched values with their index positions
    unmatched = defaultdict(list)
    nullifying_indices = set()

    for idx, row in df.iterrows():
        value = row['Val/COArea Crcy']
        opposite_value = -value

        if opposite_value in unmatched:
            # Match with the first occurrence of opposite value
            match_idx = unmatched[opposite_value].pop(0)
            nullifying_indices.update([idx, match_idx])

            # Remove the key if no more unmatched values exist
            if not unmatched[opposite_value]:
                del unmatched[opposite_value]
        else:
            # Store index of the current unmatched value
            unmatched[value].append(idx)

    # Filter DataFrame to include only nullifying rows
    return df.loc[list(nullifying_indices)]


def get_fur(wbs_code):

    # Create an empty dataframe
    wbs_breakup = pd.DataFrame()

    # Check for SB entries
    df = transaction[
        (transaction['Project definition'] == wbs_code) &
        (transaction['Document type'] == 'SB')
    ]

    # Step 2
    if df.shape[0] == 0:
        wbs_breakup = pd.concat([
            wbs_breakup,
            transaction[
                transaction['Project definition'] == wbs_code
            ]
        ], ignore_index=True)

        return wbs_breakup

    else:
        # Sort
        df = df.sort_values(by=['Fiscal Year', 'Val/COArea Crcy'], ascending=[True, False]).copy()

        # Step 3
        df_nullified = find_nullifying_groups(df)

        # Step 4
        data_non_null = df[~df['Ref. document number'].isin(df_nullified['Ref. document number'])]

        # Step 5.1 and 5.2
        data_sb = transaction[transaction['Ref. document number'].isin(data_non_null['Ref. document number'])]

        # Step 5.3
        data_proj = data_sb[data_sb['Project definition'] != wbs_code]
        # data_proj = data_sb.copy()

        # Concatenate the final data
        project_breakup = pd.concat([wbs_breakup, data_proj], ignore_index=True)

        return project_breakup

# %% [raw]
# # Create an empty dataframe
# project_breakup = pd.DataFrame()

# %% [raw]
# # Step 1 - Pick only DR & SB entries
# final_data = final_data[final_data['Document type'].isin(['DR', 'SB'])]

# %% [raw]
# # Step 2 - Loop through each Project-=]\
# for proj in final_data['Object'].unique():
#
#     # Check for SB entries
#     data = final_data[
#         (final_data['Object'] == proj) &
#         (final_data['Document type'] == 'SB')
#     ]
#
#     # Step 2
#     if data.shape[0] == 0:
#         project_breakup = pd.concat([
#             project_breakup,
#             final_data[
#                 final_data['Object'] == proj
#             ]
#         ], ignore_index=True)
#
#     else:
#
#         # Step 3
#         nullifying_groups = find_nullifying_groups(data)
#
#         # Step 4
#         data_non_null = data[~data['Ref. document number'].isin(nullifying_groups['Ref. document number'])]
#
#         # Step 5.1 and 5.2
#         data_sb = final_data[final_data['Ref. document number'].isin(data_non_null['Ref. document number'])]
#
#         # Step 5.3
#         data_proj = data_sb[data_sb['Object'] != proj]
#
#         # Concatenate the final data
#         project_breakup = pd.concat([project_breakup, data_proj], ignore_index=True)

# %% [raw]
# project_breakup

# %% [raw]
# final_data.head()

# %% [markdown]
# ### Logic 3

# %% [markdown]
# - Pick out only the DR Projects
# - Ignore below project types
#     - Legacy
#     - HF Donations
#     - CSR Donations
# - Get the non-ignored data
# - For the non-ignored project types, categorise it

# %%
final_data = final_data_bak.copy()

# %%
# Step 1
dr_data = final_data[final_data['Document type'] == 'DR'].copy()

# %%
dr_data['Val/COArea Crcy'].sum()
# Out:
# np.float64(-1535617446.1999998)

# %%
# Step 2.1
lp_data = dr_data[
    (dr_data['Project definition'].str.contains('LP')) |
    (dr_data['Object'].str.contains('LP'))
]

# %%
# Step 2.2
hf_data = dr_data[
    (dr_data['Project definition'].str.contains('HF')) |
    (dr_data['Object'].str.contains('HF'))
]

# %%
# Step 2.3
csr_data = dr_data[
    (dr_data['Project definition'].str.contains('CSRP')) |
    (dr_data['Object'].str.contains('CSRP'))
]

# %%
# Step 3
dr_data_non_ignored = dr_data[
    # Ignore Legacy Projects
    (
        ~(dr_data['Project definition'].isin(lp_data['Project definition'])) |
        ~(dr_data['Object'].isin(lp_data['Object']))
    ) &

    # Ignore HF Projects
    (
        ~(dr_data['Project definition'].isin(hf_data['Project definition'])) |
        ~(dr_data['Object'].isin(hf_data['Object']))
    ) &

    # Ignore CSR Projects
    (
        ~(dr_data['Project definition'].isin(csr_data['Project definition'])) |
        ~(dr_data['Object'].isin(csr_data['Object']))
    )
]

# %%
lp_data['Project definition'].drop_duplicates()
# Out:
# 117724    DO/2000-LP74
# 118747    DO/2003-LP76
# 121480    DO/2014-CLLP
# 122403    DO/2017-LP92
# 124282    DO/2019-LP94
# 129739    DO/2021-LP96
# 132224    DO/2022-LP10
# 132228    DO/2022-LP97
# 134862    DO/2023-LP83
# 137626    DO/2024-LP08
# 137629    DO/2024-LP14
# 137630    DO/2024-LP99
# Name: Project definition, dtype: object

# %%
for proj in lp_data['Project definition'].drop_duplicates().to_list():
    file_name = proj.replace('/', '_')
    get_fur(proj).to_csv(f'{file_name}.csv', index=False, quoting=1, lineterminator='\r\n')

# %%
# Project Breakup
fur_breakup = get_fur('DO/2000-LP74')

# %%
fur_breakup
# Out:
#     Ref. document number Posting Date Document Date Document type  \
# 0             2226006535   2022-11-02    2022-11-01            SB
# 1             2226006535   2022-11-02    2022-11-01            SB
# 2             2226009822   2023-01-16    2023-01-16            SB
# 3             2226007464   2022-11-22    2022-11-22            SB
# 4             2226007464   2022-11-22    2022-11-22            SB
# ..                   ...          ...           ...           ...
# 124           2426010109   2024-12-27    2024-12-27            SB
# 125           2426010109   2024-12-27    2024-12-27            SB
# 126           2426004221   2024-08-02    2024-08-02            SB
# 127           2426010109   2024-12-27    2024-12-27            SB
# 128           2426004219   2024-08-02    2024-08-02            SB
#
#     Project definition               Object  Fiscal Year  Cost Element  \
# 0         DO/2003-HLRF      DO/2003-HLRFREV         2022        550508
# 1         DO/2003-HLRF      DO/2003-HLRFREV         2022        550508
# 2         DO/2005-BHFS      DO/2005-BHFS001         2022        550509
# 3         DO/2006-RVNF      DO/2006-RVNF001         2022        550509
# 4         DO/2006-RVNF      DO/2006-RVNFREV         2022        550508
# ..                 ...                  ...          ...           ...
# 124       DO/2022-ROAD  DO/2023-ROAD001-007         2024        550509
# 125       DO/2022-ROAD  DO/2023-ROAD001-008         2024        550509
# 126       DO/2023-JANK      DO/2023-JANK002         2024        550508
# 127       DO/2023-JANK      DO/2023-JANK002         2024        550509
# 128       DO/2024-EFED      DO/2024-EFEDREV         2024        550508
#
#             Cost element descr. Offsetting acct no.  \
# 0    Rev-Domestic (Indian fund)              550508
# 1    Rev-Domestic (Indian fund)              550508
# 2           Rev-General Expence              550509
# 3           Rev-General Expence              550509
# 4    Rev-Domestic (Indian fund)              550509
# ..                          ...                 ...
# 124         Rev-General Expence              550509
# 125         Rev-General Expence              550509
# 126  Rev-Domestic (Indian fund)              550508
# 127         Rev-General Expence              550509
# 128  Rev-Domestic (Indian fund)              550508
#
#     Name of offsetting account  Purchasing Document Purchase order text  \
# 0                 Rev-Domestic                  NaN                None
# 1                 Rev-Domestic                  NaN                None
# 2          Rev-General Expence                  NaN                None
# 3          Rev-General Expence                  NaN                None
# 4          Rev-General Expence                  NaN                None
# ..                         ...                  ...                 ...
# 124        Rev-General Expence                  NaN                None
# 125        Rev-General Expence                  NaN                None
# 126               Rev-Domestic                  NaN                None
# 127        Rev-General Expence                  NaN                None
# 128               Rev-Domestic                  NaN                None
#
#      Val/COArea Crcy           WBS                               WBS Details  \
# 0           200000.0  DO/2003-HLRF                    HOSTEL RENOVATION FUND
# 1             5000.0  DO/2003-HLRF                    HOSTEL RENOVATION FUND
# 2          8395372.6  DO/2005-BHFS      IIT BOMBAY HERITAGE FUND SCHOLARSHIP
# 3          4984111.0  DO/2006-RVNF  R.V.NILEKANI FUND FOR HOSTEL-8 MAINTENAN
# 4          4000000.0  DO/2006-RVNF  R.V.NILEKANI FUND FOR HOSTEL-8 MAINTENAN
# ..               ...           ...                                       ...
# 124        2925912.6  DO/2022-ROAD            Research Projects on Pavements
# 125       60808811.0  DO/2022-ROAD            Research Projects on Pavements
# 126        8313000.0  DO/2023-JANK                          IITBHF GRANT 248
# 127        8319770.0  DO/2023-JANK                          IITBHF GRANT 248
# 128       38477737.0  DO/2024-EFED            Fedex Infrastructure Endowment
#
#                  Sub WBS                           SUB WBS Details  \
# 0        DO/2003-HLRFREV                    HOSTEL RENOVATION FUND
# 1        DO/2003-HLRFREV                    HOSTEL RENOVATION FUND
# 2        DO/2005-BHFS001      IIT BOMBAY HERITAGE FUND SCHOLARSHIP
# 3        DO/2006-RVNF001  R.V.NILEKANI FUND FOR HOSTEL-8 MAINTENAN
# 4        DO/2006-RVNFREV  R.V.NILEKANI FUND FOR HOSTEL-8 MAINTENAN
# ..                   ...                                       ...
# 124  DO/2023-ROAD001-007  Karyavattom Sports Facility Limited (KSF
# 125  DO/2023-ROAD001-008   Chenani Nashri Tunnelway Limited (CNTL)
# 126      DO/2023-JANK002                        Hostel Development
# 127      DO/2023-JANK002                        Hostel Development
# 128      DO/2024-EFEDREV        Fedex Infrastructure Endowment-REV
#
#                                    Project Id Category
# 0                      hostel_renovation_fund      NaN
# 1                      hostel_renovation_fund      NaN
# 2        iit_bombay_heritage_fund_scholarship      NaN
# 3    r.v.nilekani_fund_for_hostel-8_maintenan      NaN
# 4    r.v.nilekani_fund_for_hostel-8_maintenan      NaN
# ..                                        ...      ...
# 124  karyavattom_sports_facility_limited_(ksf      NaN
# 125   chenani_nashri_tunnelway_limited_(cntl)      NaN
# 126                        hostel_development      NaN
# 127                        hostel_development      NaN
# 128        fedex_infrastructure_endowment-rev      NaN
#
# [129 rows x 20 columns]

# %%
lp_data[lp_data['Project definition'] == 'DO/2021-LP96']
# Out:
#        Document Number Ref. document number Posting Date Document Date  \
# 104650    1002064877.0         2406001261.0   2024-04-25    2024-04-23
# 104651    1002127036.0         2406004839.0   2024-07-16    2024-07-09
# 104652    1002133617.0         2406005018.0   2024-07-19    2024-07-15
# 104653    1002133631.0         2406005028.0   2024-07-19    2024-07-15
# 104654    1002133647.0         2406005033.0   2024-07-19    2024-07-16
# 104655    1002136589.0         2406005555.0   2024-07-24    2024-07-17
# 104656    1002161329.0         2406009215.0   2024-08-23    2024-08-19
# 104657    1002164870.0         2406009731.0   2024-08-28    2024-08-24
# 104659    1002181495.0         2406010278.0   2024-09-20    2024-09-13
# 104660    1002226917.0         2406011712.0   2024-11-04    2024-10-25
# 104661    1002244904.0         2406011982.0   2024-11-19    2024-11-08
# 104662    1002254861.0         2406012232.0   2024-12-02    2024-11-28
#
#        Document type Project definition           Object  Fiscal Year  \
# 104650            DR       DO/2021-LP96  DO/2021-LP96REV       2024.0
# 104651            DR       DO/2021-LP96  DO/2021-LP96REV       2024.0
# 104652            DR       DO/2021-LP96  DO/2021-LP96REV       2024.0
# 104653            DR       DO/2021-LP96  DO/2021-LP96REV       2024.0
# 104654            DR       DO/2021-LP96  DO/2021-LP96REV       2024.0
# 104655            DR       DO/2021-LP96  DO/2021-LP96REV       2024.0
# 104656            DR       DO/2021-LP96  DO/2021-LP96REV       2024.0
# 104657            DR       DO/2021-LP96  DO/2021-LP96REV       2024.0
# 104659            DR       DO/2021-LP96  DO/2021-LP96REV       2024.0
# 104660            DR       DO/2021-LP96  DO/2021-LP96REV       2024.0
# 104661            DR       DO/2021-LP96  DO/2021-LP96REV       2024.0
# 104662            DR       DO/2021-LP96  DO/2021-LP96REV       2024.0
#
#         Cost Element         Cost element descr.  ... Vbl. value/TranCurr.  \
# 104650      550508.0  Rev-Domestic (Indian fund)  ...            -600000.0
# 104651      550508.0  Rev-Domestic (Indian fund)  ...            -150000.0
# 104652      550508.0  Rev-Domestic (Indian fund)  ...            -100000.0
# 104653      550508.0  Rev-Domestic (Indian fund)  ...            -150000.0
# 104654      550508.0  Rev-Domestic (Indian fund)  ...             -25001.0
# 104655      550508.0  Rev-Domestic (Indian fund)  ...             -50000.0
# 104656      550508.0  Rev-Domestic (Indian fund)  ...             -83888.0
# 104657      550508.0  Rev-Domestic (Indian fund)  ...            -375000.0
# 104659      550508.0  Rev-Domestic (Indian fund)  ...             -10000.0
# 104660      550508.0  Rev-Domestic (Indian fund)  ...                -25.0
# 104661      550508.0  Rev-Domestic (Indian fund)  ...            -100000.0
# 104662      550508.0  Rev-Domestic (Indian fund)  ...            -300000.0
#
#         Vbl. value/Obj. curr Var.val.in rep.cur. Purchase order text  \
# 104650             -600000.0           -600000.0                None
# 104651             -150000.0           -150000.0                None
# 104652             -100000.0           -100000.0                None
# 104653             -150000.0           -150000.0                None
# 104654              -25001.0            -25001.0                None
# 104655              -50000.0            -50000.0                None
# 104656              -83888.0            -83888.0                None
# 104657             -375000.0           -375000.0                None
# 104659              -10000.0            -10000.0                None
# 104660                 -25.0               -25.0                None
# 104661             -100000.0           -100000.0                None
# 104662             -300000.0           -300000.0                None
#
#                  WBS                  WBS Details          Sub WBS  \
# 104650  DO/2021-LP96  Class of '96 Legacy Project  DO/2021-LP96REV
# 104651  DO/2021-LP96  Class of '96 Legacy Project  DO/2021-LP96REV
# 104652  DO/2021-LP96  Class of '96 Legacy Project  DO/2021-LP96REV
# 104653  DO/2021-LP96  Class of '96 Legacy Project  DO/2021-LP96REV
# 104654  DO/2021-LP96  Class of '96 Legacy Project  DO/2021-LP96REV
# 104655  DO/2021-LP96  Class of '96 Legacy Project  DO/2021-LP96REV
# 104656  DO/2021-LP96  Class of '96 Legacy Project  DO/2021-LP96REV
# 104657  DO/2021-LP96  Class of '96 Legacy Project  DO/2021-LP96REV
# 104659  DO/2021-LP96  Class of '96 Legacy Project  DO/2021-LP96REV
# 104660  DO/2021-LP96  Class of '96 Legacy Project  DO/2021-LP96REV
# 104661  DO/2021-LP96  Class of '96 Legacy Project  DO/2021-LP96REV
# 104662  DO/2021-LP96  Class of '96 Legacy Project  DO/2021-LP96REV
#
#                           SUB WBS Details                         Project Id  \
# 104650  Class of '96 Legacy Project - REV  class_of_'96_legacy_project_-_rev
# 104651  Class of '96 Legacy Project - REV  class_of_'96_legacy_project_-_rev
# 104652  Class of '96 Legacy Project - REV  class_of_'96_legacy_project_-_rev
# 104653  Class of '96 Legacy Project - REV  class_of_'96_legacy_project_-_rev
# 104654  Class of '96 Legacy Project - REV  class_of_'96_legacy_project_-_rev
# 104655  Class of '96 Legacy Project - REV  class_of_'96_legacy_project_-_rev
# 104656  Class of '96 Legacy Project - REV  class_of_'96_legacy_project_-_rev
# 104657  Class of '96 Legacy Project - REV  class_of_'96_legacy_project_-_rev
# 104659  Class of '96 Legacy Project - REV  class_of_'96_legacy_project_-_rev
# 104660  Class of '96 Legacy Project - REV  class_of_'96_legacy_project_-_rev
# 104661  Class of '96 Legacy Project - REV  class_of_'96_legacy_project_-_rev
# 104662  Class of '96 Legacy Project - REV  class_of_'96_legacy_project_-_rev
#
#         Category
# 104650       NaN
# 104651       NaN
# 104652       NaN
# 104653       NaN
# 104654       NaN
# 104655       NaN
# 104656       NaN
# 104657       NaN
# 104659       NaN
# 104660       NaN
# 104661       NaN
# 104662       NaN
#
# [12 rows x 33 columns]

# %%
lp_data.loc[lp_data['Project definition'] == 'DO/2021-LP96', 'Value in Obj. Crcy'].sum()
# Out:
# np.float64(-1943914.0)

# %%
final_data.head()
# Out:
#     Document Number Ref. document number Posting Date Document Date  \
# 290    1002070478.0         2406001521.0   2024-05-06    2024-05-01
# 392    1002166308.0         2426005235.0   2024-08-29    2024-08-29
# 413    1002161931.0         2426005015.0   2024-08-23    2024-08-23
# 507    1002169039.0         2449006025.0   2024-09-03    2024-09-03
# 517    1002167118.0         2426005310.0   2024-08-30    2024-08-30
#
#     Document type Project definition           Object  Fiscal Year  \
# 290            DR       DO/2009-HATS  DO/2009-HATSREV       2024.0
# 392            SB       DO/2009-INSF  DO/2009-INSFREV       2024.0
# 413            SB       DO/2009-KRAS  DO/2009-KRAS001       2024.0
# 507            SI       DO/2009-MNGP  DO/2009-MNGP001       2024.0
# 517            SB       DO/2009-MNGP  DO/2009-MNGP001       2024.0
#
#      Cost Element         Cost element descr.  ... Vbl. value/TranCurr.  \
# 290      550508.0  Rev-Domestic (Indian fund)  ...              -501.00
# 392      550509.0         Rev-General Expence  ...            -51570.48
# 413      550509.0         Rev-General Expence  ...              2475.00
# 507      510162.0                  EXP-Awards  ...             10000.00
# 517      550054.0                  REV-Awards  ...            -10000.00
#
#      Vbl. value/Obj. curr Var.val.in rep.cur. Purchase order text  \
# 290               -501.00             -501.00                None
# 392             -51570.48           -51570.48                None
# 413               2475.00             2475.00                None
# 507              10000.00            10000.00                None
# 517             -10000.00           -10000.00                None
#
#               WBS                            WBS Details          Sub WBS  \
# 290  DO/2009-HATS         HOSTEL ALUMNI TEAM STEWARDSHIP  DO/2009-HATSREV
# 392  DO/2009-INSF  INFRASTRUCTURE ( STUDENT FACILITIES )  DO/2009-INSFREV
# 413  DO/2009-KRAS      KERSAAP RUSI ANJIRBAG SCHOLARSHIP  DO/2009-KRAS001
# 507  DO/2009-MNGP                 PROF.M.N.GOPALAN PRIZE  DO/2009-MNGP001
# 517  DO/2009-MNGP                 PROF.M.N.GOPALAN PRIZE  DO/2009-MNGP001
#
#                            SUB WBS Details  \
# 290                      Hostels - Receipt
# 392  INFRASTRUCTURE ( STUDENT FACILITIES )
# 413      KERSAAP RUSI ANJIRBAG SCHOLARSHIP
# 507                 PROF.M.N.GOPALAN PRIZE
# 517                 PROF.M.N.GOPALAN PRIZE
#
#                                 Project Id        Category
# 290                      hostels_-_receipt  Infrastructure
# 392  infrastructure_(_student_facilities_)             NaN
# 413      kersaap_rusi_anjirbag_scholarship             NaN
# 507                 prof.m.n.gopalan_prize             NaN
# 517                 prof.m.n.gopalan_prize             NaN
#
# [5 rows x 33 columns]

# %%
final_data.to_csv('Final_Data.csv', index=False, quoting=1, lineterminator='\r\n')
