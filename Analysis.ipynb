# %% [markdown]
# ## Load Libraries

# %%
import pandas as pd
# import modin.pandas as pd
from dotenv import load_dotenv
import os
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# %% [markdown]
# ## Load Environment variables

# %%
# Load the .env file
load_dotenv()

# Fetch environment variables
db_address = os.getenv('DB_ADDRESS')
db_port = os.getenv('DB_PORT')
db_username = os.getenv('DB_USERNAME')
db_password = quote_plus(os.getenv('DB_PASSWORD'))
db_name = os.getenv('DB')

# %% [markdown]
# ## Functions

# %%
def get_db_connection():
    """
    Establishes a connection to the PostgreSQL database using SQLAlchemy.
    - The `postgresql+psycopg2` dialect indicates that we're using PostgreSQL as the database backend.
    - The `{DB_USER}:{DB_PASS}` part specifies the username and password to use for connections.
    - The `@{DB_IP}:{DB_PORT}` part specifies the hostname and port number to use when connecting to the database.
    - The `/`${DB}` part specifies the database name or schema to connect to.

    :return: engine.connect(): An active connection object to the PostgreSQL database.
    """
    engine = create_engine(f'postgresql://{db_username}:{db_password}@{db_address}:{db_port}/{db_name}')

    # Establish a connection to the database:
    #   - This returns an active connection object, which can be used to execute queries and interact with the database.
    return engine.connect()

def fetch_data_from_sql(query):
    """
    Fetches data from a SQL table and returns it as a pandas DataFrame.

    :param query: (str) The SQL query to execute on the database.
    :return: pd.DataFrame: A pandas DataFrame containing the results of the SQL query.
    """

    # Establish a connection to the PostgreSQL database using get_db_connection():
    conn = get_db_connection()

    # Execute the SQL query on the database and store the result in a pandas DataFrame:
    df = pd.read_sql(query, conn)

    # Close the connection to the database to free up resources:
    conn.close()

    # Return the pandas DataFrame containing the results of the SQL query:
    return df

def change_column_names(column_list, std=True):
    if std:
        return [col.strip().title().replace('_', ' ') for col in column_list]

    else:
        return [col.strip().lower().replace(' ', '_') for col in column_list]

# %% [markdown]
# ## Get Data

# %% [markdown]
# ### Transaction

# %%
query_transaction = '''
    SELECT
        *
    FROM
        erp_data.funds_received.transactions
    '''

transaction = fetch_data_from_sql(query_transaction)

# %% [markdown]
# ### Projects

# %%
 # Get existing master
query_project_dir_old = '''
        SELECT
            *
        FROM
            erp_data.funds_received.project_directory
'''

project_directory = fetch_data_from_sql(query_project_dir_old)

# Standardise column names
project_directory.columns = change_column_names(project_directory.columns)

# %% [markdown]
# ### WBS Data

# %%
query_transaction = '''
        SELECT
            *
        FROM
            erp_data.funds_received.wbs
        '''

wbs = fetch_data_from_sql(query_transaction)

# %% [markdown]
# ### Data Cleaning

# %%
# Remove extra spaces from column names
transaction_col = transaction.columns
transaction_col = [col.strip() for col in transaction_col]
transaction.columns = transaction_col

wbs_col = wbs.columns
wbs_col = [col.strip() for col in wbs_col]
wbs.columns = wbs_col

# %%
if transaction.shape[0] > 0 and wbs.shape[0] > 0 and project_directory.shape[0] > 0:
    # Perform WBS mapping
    transaction = transaction.merge(wbs[['WBS', 'WBS Details']].drop_duplicates(), how='left',
                                    left_on='Project definition', right_on='WBS')

    transaction = transaction.merge(wbs[['Sub WBS', 'SUB WBS Details']].drop_duplicates(), how='left',
                                    left_on='Object', right_on='Sub WBS')

    transaction['Project Id'] = transaction['SUB WBS Details'].apply(
        lambda x: str(x).strip().lower().replace(' ', '_'))

    # Assign Category
    transaction = transaction.merge(project_directory[['Project Id', 'Category']], how='left', on='Project Id').copy()

# %%
start_date = pd.to_datetime('01-04-2024', format='%d-%m-%Y')
end_date = pd.to_datetime('24-12-2024', format='%d-%m-%Y')

# %%
transaction['Ref. document number'] = transaction['Ref. document number'].fillna('').astype(str)

# %%
transaction['Document Number'] = transaction['Document Number'].fillna('').astype(str)

# %% [markdown]
# ### Cleaned Data

# %%
# Final Data
final_data = transaction[(transaction['Document Date'].between(start_date, end_date))]

# %%
final_data_bak = final_data.copy()

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Logic 1

# %% [markdown]
# #### Steps:
# - For Indian Donation
#     - Take all the DR data
#     - Filter by Cost Element ≠ 550510, 550511
#     - For each "Project Definition",
#         - Get the total for each Project Definition
#         - Get the corresponding "Ref. document number". There could be multiple document numbers.
#         - For each document numbers,
#             - Get all the SB entries
#             - Get the total of all SB entries
#         - Get the total of the SB entries and compare it with the total for each Project Definition
#         - If the difference is same as total for each project definition, then use the original project definition as the Sub-WBS code
#         - If the difference is less, then categorise the difference as 'Un-assigned' in the Sub-WBS code
#     - Create a Dataframe of project wise breakup for each "Project Definition"

# %%
# Step 1
dr_data = final_data[
    (final_data['Document type'] == 'DR') &

    # Step 2
    ~(final_data['Cost Element'].isin([550510, 550511]))
]

# %%
dr_data['Val/COArea Crcy'].sum()
# Out:
# np.float64(-691618872.62)

# %%
dr_data.sample(10)
# Out:
#        Document Number Ref. document number Posting Date Document Date  \
# 119325    1002208891.0         2406011451.0   2024-10-22    2024-10-18
# 124748    1002161253.0         2406009207.0   2024-08-23    2024-08-22
# 124797    1002207059.0         2406011416.0   2024-10-21    2024-10-17
# 124820    1002226900.0         2406011707.0   2024-11-04    2024-10-19
# 122360    1002178843.0         2406010140.0   2024-09-13    2024-09-12
# 124632    1002062832.0         2406001158.0   2024-04-22    2024-04-21
# 124694    1002103642.0         2406002690.0   2024-06-24    2024-06-21
# 125872    1002182997.0         2406010391.0   2024-09-23    2024-08-22
# 132093    1002088573.0         2406002037.0   2024-06-03    2024-05-18
# 124708    1002115210.0         2406003303.0   2024-07-09    2024-07-08
#
#        Document type Project definition           Object  Fiscal Year  \
# 119325            DR       DO/2023-KCOR  DO/2023-KCORREV       2024.0
# 124748            DR       DO/2000-POOL  DO/2021-POOL003       2024.0
# 124797            DR       DO/2000-POOL  DO/2021-POOL003       2024.0
# 124820            DR       DO/2000-POOL  DO/2021-POOL003       2024.0
# 122360            DR       DO/2024-RXOS  DO/2024-RXOSREV       2024.0
# 124632            DR       DO/2000-POOL  DO/2021-POOL003       2024.0
# 124694            DR       DO/2000-POOL  DO/2021-POOL003       2024.0
# 125872            DR       DO/2001-IDPF  DO/2001-IDPFREV       2024.0
# 132093            DR        DO/2007-YFA   DO/2007-YFAREV       2024.0
# 124708            DR       DO/2000-POOL  DO/2021-POOL003       2024.0
#
#         Cost Element         Cost element descr.  ... Vbl. value/TranCurr.  \
# 119325      550508.0  Rev-Domestic (Indian fund)  ...            -528000.0
# 124748      550508.0  Rev-Domestic (Indian fund)  ...              -2000.0
# 124797      550508.0  Rev-Domestic (Indian fund)  ...             -25000.0
# 124820      550508.0  Rev-Domestic (Indian fund)  ...            -285000.0
# 122360      550508.0  Rev-Domestic (Indian fund)  ...            -135348.0
# 124632      550508.0  Rev-Domestic (Indian fund)  ...             -10000.0
# 124694      550508.0  Rev-Domestic (Indian fund)  ...             -10000.0
# 125872      550508.0  Rev-Domestic (Indian fund)  ...             -10387.0
# 132093      550508.0  Rev-Domestic (Indian fund)  ...              -1000.0
# 124708      550508.0  Rev-Domestic (Indian fund)  ...              -1000.0
#
#         Vbl. value/Obj. curr Var.val.in rep.cur. Purchase order text  \
# 119325             -528000.0           -528000.0                None
# 124748               -2000.0             -2000.0                None
# 124797              -25000.0            -25000.0                None
# 124820             -285000.0           -285000.0                None
# 122360             -135348.0           -135348.0                None
# 124632              -10000.0            -10000.0                None
# 124694              -10000.0            -10000.0                None
# 125872              -10387.0            -10387.0                None
# 132093               -1000.0             -1000.0                None
# 124708               -1000.0             -1000.0                None
#
#                  WBS                               WBS Details  \
# 119325  DO/2023-KCOR              K Corp Charitable Foundation
# 124748  DO/2000-POOL                     Donation Pool Account
# 124797  DO/2000-POOL                     Donation Pool Account
# 124820  DO/2000-POOL                     Donation Pool Account
# 122360  DO/2024-RXOS                            UG Scholarship
# 124632  DO/2000-POOL                     Donation Pool Account
# 124694  DO/2000-POOL                     Donation Pool Account
# 125872  DO/2001-IDPF                INSTITUTE DEVELOPMENT FUND
# 132093   DO/2007-YFA  CLASS OF'82 LEGACY PROJECT JOINING BONUS
# 124708  DO/2000-POOL                     Donation Pool Account
#
#                 Sub WBS                   SUB WBS Details  \
# 119325  DO/2023-KCORREV  K Corp Charitable Foundation-REV
# 124748  DO/2021-POOL003              DOMESTIC SCHOLARSHIP
# 124797  DO/2021-POOL003              DOMESTIC SCHOLARSHIP
# 124820  DO/2021-POOL003              DOMESTIC SCHOLARSHIP
# 122360  DO/2024-RXOSREV                UG Scholarship-REV
# 124632  DO/2021-POOL003              DOMESTIC SCHOLARSHIP
# 124694  DO/2021-POOL003              DOMESTIC SCHOLARSHIP
# 125872  DO/2001-IDPFREV        INSTITUTE DEVELOPMENT FUND
# 132093   DO/2007-YFAREV   CLASS OF'82 LEGACY PROJECT -REV
# 124708  DO/2021-POOL003              DOMESTIC SCHOLARSHIP
#
#                               Project Id         Category
# 119325  k_corp_charitable_foundation-rev              R&D
# 124748              domestic_scholarship              NaN
# 124797              domestic_scholarship              NaN
# 124820              domestic_scholarship              NaN
# 122360                ug_scholarship-rev              NaN
# 124632              domestic_scholarship              NaN
# 124694              domestic_scholarship              NaN
# 125872        institute_development_fund  Strategic Needs
# 132093   class_of'82_legacy_project_-rev              NaN
# 124708              domestic_scholarship              NaN
#
# [10 rows x 33 columns]

# %%
project_wise_breakup = pd.DataFrame()

for proj in dr_data['Project definition'].unique():
    # Step 3
    proj_total_dr = abs(dr_data.loc[dr_data['Project definition'] == proj, 'Val/COArea Crcy'].sum())

    # Step 4
    ref_nos = final_data.loc[
        final_data['Project definition'] == proj,
        'Ref. document number'
    ]

    # Step 5
    dr_sb_entries = pd.DataFrame()
    for ref in ref_nos:
        df = final_data[
            (final_data['Ref. document number'] == ref) &
            (final_data['Document type'] =='SB')
        ]

        dr_sb_entries = pd.concat([dr_sb_entries, df], ignore_index=True)

    dr_sb_entries = dr_sb_entries.copy()

    # Step 6
    proj_total_sb = abs(dr_sb_entries['Val/COArea Crcy'].sum())

    # Step 7
    proj_total_diff = proj_total_dr - proj_total_sb

    # Step 8
    if proj_total_sb == 0:
        dr_sb_entries = dr_data[dr_data['Project definition'] == proj]
        # dr_sb_entries['Val/COArea Crcy'] = dr_sb_entries['Val/COArea Crcy'].apply(abs)

    elif proj_total_diff < proj_total_dr:
        unassigned = {
            'Val/COArea Crcy': proj_total_diff,
            'WBS': 'Unassigned',
            'WBS Details': 'Unassigned',
            'Sub WBS': 'Unassigned',
            'SUB WBS Details': 'Unassigned',
            'Project Id': 'Unassigned',
            'Category': 'Unassigned'
        }

        dr_sb_entries = pd.concat([dr_sb_entries, pd.DataFrame(data=unassigned, index=[0])], axis=0, ignore_index=True)

    elif proj_total_diff > proj_total_dr:
        print(proj, 'difference is high')

    # Step Last
    dr_sb_entries.insert(0, 'OG Project', proj)
    # og_project = pd.DataFrame(data={
    #     'OG Project': proj
    # }, index=range(0, dr_sb_entries.shape[0]))
    #
    # dr_sb_entries = pd.concat([og_project, dr_sb_entries], axis=1, ignore_index=True)

    project_wise_breakup = pd.concat([project_wise_breakup, dr_sb_entries], ignore_index=True)

# %%
project_wise_breakup['Val/COArea Crcy'].sum()
# Out:
# np.float64(20872748.519999817)

# %%
project_wise_breakup
# Out:
#         OG Project Document Number Ref. document number Posting Date  \
# 0     DO/2009-HATS    1002070478.0         2406001521.0   2024-05-06
# 1     DO/2014-PDMA    1002199191.0         2426007228.0   2024-10-11
# 2     DO/2014-PDMA    1002199191.0         2426007228.0   2024-10-11
# 3     DO/2014-PDMA    1002199191.0         2426007228.0   2024-10-11
# 4     DO/2014-PDMA    1002199191.0         2426007228.0   2024-10-11
# ...            ...             ...                  ...          ...
# 6320   DO/2007-YFA    1002236256.0         2426008214.0   2024-11-07
# 6321   DO/2007-YFA    1002236256.0         2426008214.0   2024-11-07
# 6322   DO/2007-YFA             NaN                  NaN          NaN
# 6323  DO/2007-SSDF    1002068501.0         2406001467.0   2024-05-02
# 6324  DO/2007-SSDF    1002089118.0         2406002061.0   2024-06-03
#
#      Document Date Document type Project definition           Object  \
# 0       2024-05-01            DR       DO/2009-HATS  DO/2009-HATSREV
# 1       2024-10-11            SB       DO/2014-PDMA  DO/2014-PDMA001
# 2       2024-10-11            SB       DO/2014-PDMA  DO/2014-PDMA001
# 3       2024-10-11            SB       DO/2014-PDMA  DO/2014-PDMAREV
# 4       2024-10-11            SB       DO/2000-POOL  DO/2000-POOL002
# ...            ...           ...                ...              ...
# 6320    2024-10-25            SB        DO/2007-YFA   DO/2007-YFAREV
# 6321    2024-10-25            SB        DO/2007-YFA   DO/2024-YFA002
# 6322           NaT           NaN                NaN              NaN
# 6323    2024-04-26            DR       DO/2007-SSDF  DO/2007-SSDFREV
# 6324    2024-05-12            DR       DO/2007-SSDF  DO/2007-SSDFREV
#
#       Fiscal Year  Cost Element  ... Vbl. value/TranCurr.  \
# 0          2024.0      550508.0  ...               -501.0
# 1          2024.0      510508.0  ...             -10000.0
# 2          2024.0      550512.0  ...              10000.0
# 3          2024.0      550509.0  ...             -10000.0
# 4          2024.0      550512.0  ...              10000.0
# ...           ...           ...  ...                  ...
# 6320       2024.0      550508.0  ...            2996367.0
# 6321       2024.0      550508.0  ...           -2996367.0
# 6322          NaN           NaN  ...                  NaN
# 6323       2024.0      550508.0  ...                -25.0
# 6324       2024.0      550508.0  ...                -25.0
#
#      Vbl. value/Obj. curr  Var.val.in rep.cur. Purchase order text  \
# 0                  -501.0               -501.0                None
# 1                -10000.0             -10000.0                None
# 2                 10000.0              10000.0                None
# 3                -10000.0             -10000.0                None
# 4                 10000.0              10000.0                None
# ...                   ...                  ...                 ...
# 6320            2996367.0            2996367.0                None
# 6321           -2996367.0           -2996367.0                None
# 6322                  NaN                  NaN                None
# 6323                -25.0                -25.0                None
# 6324                -25.0                -25.0                None
#
#                WBS                               WBS Details          Sub WBS  \
# 0     DO/2009-HATS            HOSTEL ALUMNI TEAM STEWARDSHIP  DO/2009-HATSREV
# 1     DO/2014-PDMA  SHRIMATI PRAKASHVATI DEVI GUPTA MERIT AW  DO/2014-PDMA001
# 2     DO/2014-PDMA  SHRIMATI PRAKASHVATI DEVI GUPTA MERIT AW  DO/2014-PDMA001
# 3     DO/2014-PDMA  SHRIMATI PRAKASHVATI DEVI GUPTA MERIT AW  DO/2014-PDMAREV
# 4     DO/2000-POOL                     Donation Pool Account  DO/2000-POOL002
# ...            ...                                       ...              ...
# 6320   DO/2007-YFA  CLASS OF'82 LEGACY PROJECT JOINING BONUS   DO/2007-YFAREV
# 6321   DO/2007-YFA  CLASS OF'82 LEGACY PROJECT JOINING BONUS   DO/2024-YFA002
# 6322    Unassigned                                Unassigned       Unassigned
# 6323  DO/2007-SSDF            SCHOLARSHIPS&STUDENT DEVT.FUND  DO/2007-SSDFREV
# 6324  DO/2007-SSDF            SCHOLARSHIPS&STUDENT DEVT.FUND  DO/2007-SSDFREV
#
#                                SUB WBS Details  \
# 0                            Hostels - Receipt
# 1     SHRIMATI PRAKASHVATI DEVI GUPTA MERIT AW
# 2     SHRIMATI PRAKASHVATI DEVI GUPTA MERIT AW
# 3     SHRIMATI PRAKASHVATI DEVI GUPTA MERIT AW
# 4                          IIT BHF SCHOLARSHIP
# ...                                        ...
# 6320           CLASS OF'82 LEGACY PROJECT -REV
# 6321                  Young Faculty Fellowship
# 6322                                Unassigned
# 6323            SCHOLARSHIPS&STUDENT DEVT.FUND
# 6324            SCHOLARSHIPS&STUDENT DEVT.FUND
#
#                                     Project Id        Category
# 0                            hostels_-_receipt  Infrastructure
# 1     shrimati_prakashvati_devi_gupta_merit_aw             NaN
# 2     shrimati_prakashvati_devi_gupta_merit_aw             NaN
# 3     shrimati_prakashvati_devi_gupta_merit_aw             NaN
# 4                          iit_bhf_scholarship             NaN
# ...                                        ...             ...
# 6320           class_of'82_legacy_project_-rev             NaN
# 6321                  young_faculty_fellowship             NaN
# 6322                                Unassigned      Unassigned
# 6323            scholarships&student_devt.fund             NaN
# 6324            scholarships&student_devt.fund             NaN
#
# [6325 rows x 34 columns]

# %%
dr_data.loc[dr_data['Project definition'] == proj, 'Val/COArea Crcy'].sum()
# Out:
# np.float64(-50.0)

# %%
dr_data[dr_data['Project definition'] == proj]
# Out:
#        Document Number Ref. document number Posting Date Document Date  \
# 132635    1002068501.0         2406001467.0   2024-05-02    2024-04-26
# 132636    1002089118.0         2406002061.0   2024-06-03    2024-05-12
#
#        Document type Project definition           Object  Fiscal Year  \
# 132635            DR       DO/2007-SSDF  DO/2007-SSDFREV       2024.0
# 132636            DR       DO/2007-SSDF  DO/2007-SSDFREV       2024.0
#
#         Cost Element         Cost element descr.  ... Vbl. value/TranCurr.  \
# 132635      550508.0  Rev-Domestic (Indian fund)  ...                -25.0
# 132636      550508.0  Rev-Domestic (Indian fund)  ...                -25.0
#
#         Vbl. value/Obj. curr Var.val.in rep.cur. Purchase order text  \
# 132635                 -25.0               -25.0                None
# 132636                 -25.0               -25.0                None
#
#                  WBS                     WBS Details          Sub WBS  \
# 132635  DO/2007-SSDF  SCHOLARSHIPS&STUDENT DEVT.FUND  DO/2007-SSDFREV
# 132636  DO/2007-SSDF  SCHOLARSHIPS&STUDENT DEVT.FUND  DO/2007-SSDFREV
#
#                        SUB WBS Details                      Project Id  \
# 132635  SCHOLARSHIPS&STUDENT DEVT.FUND  scholarships&student_devt.fund
# 132636  SCHOLARSHIPS&STUDENT DEVT.FUND  scholarships&student_devt.fund
#
#         Category
# 132635       NaN
# 132636       NaN
#
# [2 rows x 33 columns]

# %%
dr_sb_entries
# Out:
#           OG Project Document Number Ref. document number Posting Date  \
# 132635  DO/2007-SSDF    1002068501.0         2406001467.0   2024-05-02
# 132636  DO/2007-SSDF    1002089118.0         2406002061.0   2024-06-03
#
#        Document Date Document type Project definition           Object  \
# 132635    2024-04-26            DR       DO/2007-SSDF  DO/2007-SSDFREV
# 132636    2024-05-12            DR       DO/2007-SSDF  DO/2007-SSDFREV
#
#         Fiscal Year  Cost Element  ... Vbl. value/TranCurr.  \
# 132635       2024.0      550508.0  ...                -25.0
# 132636       2024.0      550508.0  ...                -25.0
#
#        Vbl. value/Obj. curr  Var.val.in rep.cur. Purchase order text  \
# 132635                -25.0                -25.0                None
# 132636                -25.0                -25.0                None
#
#                  WBS                     WBS Details          Sub WBS  \
# 132635  DO/2007-SSDF  SCHOLARSHIPS&STUDENT DEVT.FUND  DO/2007-SSDFREV
# 132636  DO/2007-SSDF  SCHOLARSHIPS&STUDENT DEVT.FUND  DO/2007-SSDFREV
#
#                        SUB WBS Details                      Project Id  \
# 132635  SCHOLARSHIPS&STUDENT DEVT.FUND  scholarships&student_devt.fund
# 132636  SCHOLARSHIPS&STUDENT DEVT.FUND  scholarships&student_devt.fund
#
#         Category
# 132635       NaN
# 132636       NaN
#
# [2 rows x 34 columns]

# %%
final_data.sample(10)
# Out:
#        Document Number Ref. document number Posting Date Document Date  \
# 97273     1002155775.0         2417017460.0   2024-08-27    2024-08-13
# 74508     1002102577.0         2426002320.0   2024-06-20    2024-06-19
# 117862    1002186187.0             153894.0   2024-09-30    2024-09-30
# 70855     1002211537.0         2417027866.0   2024-11-12    2024-10-10
# 95895     1002068524.0         2417001861.0   2024-05-02    2024-04-15
# 110544    1002126443.0         2426003375.0   2024-07-15    2024-07-15
# 96789     1002148114.0         2417013816.0   2024-08-05    2024-06-17
# 133653    1002136384.0         2426003754.0   2024-07-23    2024-07-22
# 115654    1002165721.0         2426005207.0   2024-08-28    2024-08-28
# 75175     1002099860.0         2417006770.0   2024-06-14    2024-06-03
#
#        Document type Project definition               Object  Fiscal Year  \
# 97273             KR       DO/2021-DCIL      DO/2021-DCIL001       2024.0
# 74508             SB       DO/2019-CSRP      DO/2021-ATPL001       2024.0
# 117862            H6       DO/2023-BEEK      DO/2023-BEEK001       2024.0
# 70855             KR       DO/2018-SVCF      DO/2018-SVCF001       2024.0
# 95895             KR       DO/2021-COGE  DO/2021-COGE002-010       2024.0
# 110544            SB      DO/2021-TCA21  DO/2021-TCAI002-004       2024.0
# 96789             KR       DO/2021-COGE  DO/2024-COGE002-018       2024.0
# 133653            SB       DO/2009-BHFL      DO/2009-BHFL001       2024.0
# 115654            SB       DO/2022-SBST      DO/2022-SBST001       2024.0
# 75175             KR       DO/2019-CSRP         DO/2021-MLSP       2024.0
#
#         Cost Element         Cost element descr.  ... Vbl. value/TranCurr.  \
# 97273       510150.0           EXP-CONTINGENCIES  ...              12500.0
# 74508       510076.0           EXP-OTHER CHARGES  ...               6660.0
# 117862      611104.0  Pay & Allowances - Project  ...              47000.0
# 70855       510506.0            Tour and Travels  ...              35229.0
# 95895       510148.0             EXP-CONSUMABLES  ...              24980.6
# 110544      550001.0         Rev-EQUIPMENT&TOOLS  ...             100000.0
# 96789       510506.0            Tour and Travels  ...               1050.0
# 133653      550509.0         Rev-General Expence  ...             400000.0
# 115654      550020.0             Rev-CONSUMABLES  ...            2000000.0
# 75175       510148.0             EXP-CONSUMABLES  ...              13570.0
#
#         Vbl. value/Obj. curr Var.val.in rep.cur. Purchase order text  \
# 97273                12500.0             12500.0                None
# 74508                 6660.0              6660.0                None
# 117862               47000.0             47000.0                None
# 70855                35229.0             35229.0                None
# 95895                24980.6             24980.6                None
# 110544              100000.0            100000.0                None
# 96789                 1050.0              1050.0                None
# 133653              400000.0            400000.0                None
# 115654             2000000.0           2000000.0                None
# 75175                13570.0             13570.0                None
#
#                   WBS                               WBS Details  \
# 97273    DO/2021-DCIL  Dissemination of innovative rural techno
# 74508    DO/2019-CSRP                               CSR PROJECT
# 117862   DO/2023-BEEK  Beekeeping Program Interventions to Boos
# 70855    DO/2018-SVCF   SILICON VALLEY COMM.FOUNDATION/ UNIV OF
# 95895    DO/2021-COGE  Center of excellence in Oil,Gas & Energy
# 110544  DO/2021-TCA21         TechnoCraft Center for Applied AI
# 96789    DO/2021-COGE  Center of excellence in Oil,Gas & Energy
# 133653   DO/2009-BHFL                      BHARAT FORGE LIMITED
# 115654   DO/2022-SBST  IITB Trust Lab- Dr.Shridhar Shukla funds
# 75175    DO/2019-CSRP                               CSR PROJECT
#
#                     Sub WBS                           SUB WBS Details  \
# 97273       DO/2021-DCIL001      Dissemination of inno. rural tec EXP
# 74508       DO/2021-ATPL001                Ani Technologies Pvt. Ltd.
# 117862      DO/2023-BEEK001      Beekeeping Program Interventions-EXP
# 70855       DO/2018-SVCF001   SILICON VALLEY COMM.FOUNDATION/ UNIV OF
# 95895   DO/2021-COGE002-010    Estimation of CO2 storage potential in
# 110544  DO/2021-TCAI002-004                Labeling 3D medical images
# 96789   DO/2024-COGE002-018  Enhanced coalbed methane recovery with p
# 133653      DO/2009-BHFL001                           MEMS DEPTT BHFL
# 115654      DO/2022-SBST001  IITB Trust Lab -Dr.Shridhar Shukla funds
# 75175          DO/2021-MLSP  Development of Clinical tests for Covid-
#
#                                       Project Id  Category
# 97273       dissemination_of_inno._rural_tec_exp       NaN
# 74508                 ani_technologies_pvt._ltd.       NaN
# 117862      beekeeping_program_interventions-exp       NaN
# 70855    silicon_valley_comm.foundation/_univ_of       NaN
# 95895     estimation_of_co2_storage_potential_in       NaN
# 110544                labeling_3d_medical_images       NaN
# 96789   enhanced_coalbed_methane_recovery_with_p       NaN
# 133653                           mems_deptt_bhfl       NaN
# 115654  iitb_trust_lab_-dr.shridhar_shukla_funds       NaN
# 75175   development_of_clinical_tests_for_covid-       NaN
#
# [10 rows x 33 columns]

# %%
final_data[final_data['SUB WBS Details'].fillna('').str.contains('91')]
# Out:
#       Document Number Ref. document number Posting Date Document Date  \
# 46860    1002235578.0         2426008190.0   2024-11-07    2024-11-07
# 46868    1002235578.0         2426008190.0   2024-11-07    2024-11-07
# 46869    1002148858.0         2426004303.0   2024-08-06    2024-08-06
# 46870    1002148858.0         2426004303.0   2024-08-06    2024-08-06
# 46871    1002148858.0         2426004303.0   2024-08-06    2024-08-06
# 46872    1002148858.0         2426004303.0   2024-08-06    2024-08-06
# 46873    1002148858.0         2426004303.0   2024-08-06    2024-08-06
# 46874    1002148858.0         2426004303.0   2024-08-06    2024-08-06
# 46875    1002148858.0         2426004303.0   2024-08-06    2024-08-06
# 46876    1002240240.0         2426008393.0   2024-11-11    2024-11-11
# 46878    1002240240.0         2426008393.0   2024-11-11    2024-11-11
# 46926    1002235578.0         2426008190.0   2024-11-07    2024-11-07
# 46927    1002240240.0         2426008393.0   2024-11-11    2024-11-11
#
#       Document type Project definition           Object  Fiscal Year  \
# 46860            SB       DO/2015-LP91  DO/2015-LP91001       2024.0
# 46868            SB       DO/2015-LP91  DO/2015-LP91001       2024.0
# 46869            SB       DO/2015-LP91  DO/2015-LP91001       2024.0
# 46870            SB       DO/2015-LP91  DO/2015-LP91001       2024.0
# 46871            SB       DO/2015-LP91  DO/2015-LP91001       2024.0
# 46872            SB       DO/2015-LP91  DO/2015-LP91001       2024.0
# 46873            SB       DO/2015-LP91  DO/2015-LP91001       2024.0
# 46874            SB       DO/2015-LP91  DO/2015-LP91001       2024.0
# 46875            SB       DO/2015-LP91  DO/2015-LP91001       2024.0
# 46876            SB       DO/2015-LP91  DO/2015-LP91001       2024.0
# 46878            SB       DO/2015-LP91  DO/2015-LP91001       2024.0
# 46926            SB       DO/2015-LP91  DO/2015-LP91REV       2024.0
# 46927            SB       DO/2015-LP91  DO/2015-LP91REV       2024.0
#
#        Cost Element         Cost element descr.  ... Vbl. value/TranCurr.  \
# 46860      510225.0             EXP-ADMIN. EXP.  ...            -15000.00
# 46868      550149.0              REV-ADMIN.EXP.  ...             15000.00
# 46869      550508.0  Rev-Domestic (Indian fund)  ...           -637795.50
# 46870      550508.0  Rev-Domestic (Indian fund)  ...          -1247186.55
# 46871      550508.0  Rev-Domestic (Indian fund)  ...          -2756927.23
# 46872      550508.0  Rev-Domestic (Indian fund)  ...          -2429451.31
# 46873      550508.0  Rev-Domestic (Indian fund)  ...          -2606628.30
# 46874      550508.0  Rev-Domestic (Indian fund)  ...          -2874166.13
# 46875      550508.0  Rev-Domestic (Indian fund)  ...          -2874166.13
# 46876      550509.0         Rev-General Expence  ...          15426321.15
# 46878      550028.0           REV-OTHER CHARGES  ...           2043636.60
# 46926      550509.0         Rev-General Expence  ...            -15000.00
# 46927      550509.0         Rev-General Expence  ...          45538930.43
#
#        Vbl. value/Obj. curr Var.val.in rep.cur. Purchase order text  \
# 46860             -15000.00           -15000.00                None
# 46868              15000.00            15000.00                None
# 46869            -637795.50          -637795.50                None
# 46870           -1247186.55         -1247186.55                None
# 46871           -2756927.23         -2756927.23                None
# 46872           -2429451.31         -2429451.31                None
# 46873           -2606628.30         -2606628.30                None
# 46874           -2874166.13         -2874166.13                None
# 46875           -2874166.13         -2874166.13                None
# 46876           15426321.15         15426321.15                None
# 46878            2043636.60          2043636.60                None
# 46926             -15000.00           -15000.00                None
# 46927           45538930.43         45538930.43                None
#
#                 WBS                   WBS Details          Sub WBS  \
# 46860  DO/2015-LP91  CLASS OF 1991 LEGACY PROJECT  DO/2015-LP91001
# 46868  DO/2015-LP91  CLASS OF 1991 LEGACY PROJECT  DO/2015-LP91001
# 46869  DO/2015-LP91  CLASS OF 1991 LEGACY PROJECT  DO/2015-LP91001
# 46870  DO/2015-LP91  CLASS OF 1991 LEGACY PROJECT  DO/2015-LP91001
# 46871  DO/2015-LP91  CLASS OF 1991 LEGACY PROJECT  DO/2015-LP91001
# 46872  DO/2015-LP91  CLASS OF 1991 LEGACY PROJECT  DO/2015-LP91001
# 46873  DO/2015-LP91  CLASS OF 1991 LEGACY PROJECT  DO/2015-LP91001
# 46874  DO/2015-LP91  CLASS OF 1991 LEGACY PROJECT  DO/2015-LP91001
# 46875  DO/2015-LP91  CLASS OF 1991 LEGACY PROJECT  DO/2015-LP91001
# 46876  DO/2015-LP91  CLASS OF 1991 LEGACY PROJECT  DO/2015-LP91001
# 46878  DO/2015-LP91  CLASS OF 1991 LEGACY PROJECT  DO/2015-LP91001
# 46926  DO/2015-LP91  CLASS OF 1991 LEGACY PROJECT  DO/2015-LP91REV
# 46927  DO/2015-LP91  CLASS OF 1991 LEGACY PROJECT  DO/2015-LP91REV
#
#                             SUB WBS Details  \
# 46860          CLASS OF 1991 LEGACY PROJECT
# 46868          CLASS OF 1991 LEGACY PROJECT
# 46869          CLASS OF 1991 LEGACY PROJECT
# 46870          CLASS OF 1991 LEGACY PROJECT
# 46871          CLASS OF 1991 LEGACY PROJECT
# 46872          CLASS OF 1991 LEGACY PROJECT
# 46873          CLASS OF 1991 LEGACY PROJECT
# 46874          CLASS OF 1991 LEGACY PROJECT
# 46875          CLASS OF 1991 LEGACY PROJECT
# 46876          CLASS OF 1991 LEGACY PROJECT
# 46878          CLASS OF 1991 LEGACY PROJECT
# 46926  CLASS OF 1991 LEGACY PROJECT Receipt
# 46927  CLASS OF 1991 LEGACY PROJECT Receipt
#
#                                  Project Id  Category
# 46860          class_of_1991_legacy_project       NaN
# 46868          class_of_1991_legacy_project       NaN
# 46869          class_of_1991_legacy_project       NaN
# 46870          class_of_1991_legacy_project       NaN
# 46871          class_of_1991_legacy_project       NaN
# 46872          class_of_1991_legacy_project       NaN
# 46873          class_of_1991_legacy_project       NaN
# 46874          class_of_1991_legacy_project       NaN
# 46875          class_of_1991_legacy_project       NaN
# 46876          class_of_1991_legacy_project       NaN
# 46878          class_of_1991_legacy_project       NaN
# 46926  class_of_1991_legacy_project_receipt       NaN
# 46927  class_of_1991_legacy_project_receipt       NaN
#
# [13 rows x 33 columns]

# %%
data_1 = fetch_data_from_sql('''
SELECT
    *
FROM
    erp_data.funds_received.transactions
WHERE
    "Project definition" LIKE '%%91%%' AND
    "Document type" = 'SB'
''')

# %%
data_1
# Out:
#     Document Number  Ref. document number Posting Date Document Date  \
# 0      1.000198e+09          1.826006e+09   2018-10-05    2017-12-07
# 1      1.000473e+09          1.926002e+09   2019-06-19    2019-06-19
# 2      1.000633e+09          1.926009e+09   2019-12-24    2019-12-23
# 3      1.000743e+09          1.926013e+09   2020-03-11    2020-03-11
# 4      1.001492e+09          2.226006e+09   2022-10-10    2022-10-10
# 5      1.002236e+09          2.426008e+09   2024-11-07    2024-11-07
# 6      1.002240e+09          2.426008e+09   2024-11-11    2024-11-11
# 7      1.001030e+09          2.026010e+09   2021-03-26    2021-03-26
# 8      1.001493e+09          2.226006e+09   2022-10-10    2022-10-10
# 9      1.002236e+09          2.426008e+09   2024-11-07    2024-11-07
# 10     1.000473e+09          1.926002e+09   2019-06-19    2019-06-19
# 11     1.001492e+09          2.226006e+09   2022-10-10    2022-10-10
# 12     1.002236e+09          2.426008e+09   2024-11-07    2024-11-07
# 13     1.002149e+09          2.426004e+09   2024-08-06    2024-08-06
# 14     1.002149e+09          2.426004e+09   2024-08-06    2024-08-06
# 15     1.002149e+09          2.426004e+09   2024-08-06    2024-08-06
# 16     1.002149e+09          2.426004e+09   2024-08-06    2024-08-06
# 17     1.002149e+09          2.426004e+09   2024-08-06    2024-08-06
# 18     1.002149e+09          2.426004e+09   2024-08-06    2024-08-06
# 19     1.002149e+09          2.426004e+09   2024-08-06    2024-08-06
# 20     1.002240e+09          2.426008e+09   2024-11-11    2024-11-11
# 21     1.000633e+09          1.926009e+09   2019-12-24    2019-12-23
# 22     1.002240e+09          2.426008e+09   2024-11-11    2024-11-11
#
#    Document type Project definition           Object  Fiscal Year  \
# 0             SB       DO/2015-LP91  DO/2015-LP91REV       2018.0
# 1             SB       DO/2015-LP91  DO/2015-LP91REV       2019.0
# 2             SB       DO/2015-LP91  DO/2015-LP91REV       2019.0
# 3             SB       DO/2015-LP91  DO/2015-LP91REV       2019.0
# 4             SB       DO/2015-LP91  DO/2015-LP91REV       2022.0
# 5             SB       DO/2015-LP91  DO/2015-LP91REV       2024.0
# 6             SB       DO/2015-LP91  DO/2015-LP91REV       2024.0
# 7             SB       DO/2015-LP91  DO/2015-LP91REV       2020.0
# 8             SB       DO/2015-LP91  DO/2015-LP91001       2022.0
# 9             SB       DO/2015-LP91  DO/2015-LP91001       2024.0
# 10            SB       DO/2015-LP91  DO/2015-LP91001       2019.0
# 11            SB       DO/2015-LP91  DO/2015-LP91001       2022.0
# 12            SB       DO/2015-LP91  DO/2015-LP91001       2024.0
# 13            SB       DO/2015-LP91  DO/2015-LP91001       2024.0
# 14            SB       DO/2015-LP91  DO/2015-LP91001       2024.0
# 15            SB       DO/2015-LP91  DO/2015-LP91001       2024.0
# 16            SB       DO/2015-LP91  DO/2015-LP91001       2024.0
# 17            SB       DO/2015-LP91  DO/2015-LP91001       2024.0
# 18            SB       DO/2015-LP91  DO/2015-LP91001       2024.0
# 19            SB       DO/2015-LP91  DO/2015-LP91001       2024.0
# 20            SB       DO/2015-LP91  DO/2015-LP91001       2024.0
# 21            SB       DO/2015-LP91  DO/2015-LP91001       2019.0
# 22            SB       DO/2015-LP91  DO/2015-LP91001       2024.0
#
#     Cost Element         Cost element descr.  ... Exchange Rate Type  \
# 0       550509.0         Rev-General Expence  ...                  M
# 1       550509.0         Rev-General Expence  ...                  M
# 2       550509.0         Rev-General Expence  ...                  M
# 3       550509.0         Rev-General Expence  ...                  M
# 4       550509.0         Rev-General Expence  ...                  M
# 5       550509.0         Rev-General Expence  ...                  M
# 6       550509.0         Rev-General Expence  ...                  M
# 7       550511.0         Rev-IITBHF Donation  ...                  M
# 8       510225.0             EXP-ADMIN. EXP.  ...                  M
# 9       510225.0             EXP-ADMIN. EXP.  ...                  M
# 10      510076.0           EXP-OTHER CHARGES  ...                  M
# 11      550149.0              REV-ADMIN.EXP.  ...                  M
# 12      550149.0              REV-ADMIN.EXP.  ...                  M
# 13      550508.0  Rev-Domestic (Indian fund)  ...                  M
# 14      550508.0  Rev-Domestic (Indian fund)  ...                  M
# 15      550508.0  Rev-Domestic (Indian fund)  ...                  M
# 16      550508.0  Rev-Domestic (Indian fund)  ...                  M
# 17      550508.0  Rev-Domestic (Indian fund)  ...                  M
# 18      550508.0  Rev-Domestic (Indian fund)  ...                  M
# 19      550508.0  Rev-Domestic (Indian fund)  ...                  M
# 20      550509.0         Rev-General Expence  ...                  M
# 21      550028.0           REV-OTHER CHARGES  ...                  M
# 22      550028.0           REV-OTHER CHARGES  ...                  M
#
#     Value Type Value in Obj. Crcy Report currency Val.in rep.cur.  \
# 0          4.0         4000000.00             INR      4000000.00
# 1          4.0          205792.00             INR       205792.00
# 2          4.0         2600000.00             INR      2600000.00
# 3          4.0         -750000.00             INR      -750000.00
# 4          4.0           15000.00             INR        15000.00
# 5          4.0          -15000.00             INR       -15000.00
# 6          4.0        45538930.43             INR     45538930.43
# 7          4.0        -2293539.80             INR     -2293539.80
# 8          4.0           15000.00             INR        15000.00
# 9          4.0          -15000.00             INR       -15000.00
# 10         4.0         -205792.00             INR      -205792.00
# 11         4.0          -15000.00             INR       -15000.00
# 12         4.0           15000.00             INR        15000.00
# 13         4.0         -637795.50             INR      -637795.50
# 14         4.0        -1247186.55             INR     -1247186.55
# 15         4.0        -2756927.23             INR     -2756927.23
# 16         4.0        -2429451.31             INR     -2429451.31
# 17         4.0        -2606628.30             INR     -2606628.30
# 18         4.0        -2874166.13             INR     -2874166.13
# 19         4.0        -2874166.13             INR     -2874166.13
# 20         4.0        15426321.15             INR     15426321.15
# 21         4.0        -2600000.00             INR     -2600000.00
# 22         4.0         2043636.60             INR      2043636.60
#
#    Vbl.Val./COCrcy Vbl. value/TranCurr. Vbl. value/Obj. curr  \
# 0       4000000.00           4000000.00           4000000.00
# 1        205792.00            205792.00            205792.00
# 2       2600000.00           2600000.00           2600000.00
# 3       -750000.00           -750000.00           -750000.00
# 4         15000.00             15000.00             15000.00
# 5        -15000.00            -15000.00            -15000.00
# 6      45538930.43          45538930.43          45538930.43
# 7      -2293539.80          -2293539.80          -2293539.80
# 8         15000.00             15000.00             15000.00
# 9        -15000.00            -15000.00            -15000.00
# 10      -205792.00           -205792.00           -205792.00
# 11       -15000.00            -15000.00            -15000.00
# 12        15000.00             15000.00             15000.00
# 13      -637795.50           -637795.50           -637795.50
# 14     -1247186.55          -1247186.55          -1247186.55
# 15     -2756927.23          -2756927.23          -2756927.23
# 16     -2429451.31          -2429451.31          -2429451.31
# 17     -2606628.30          -2606628.30          -2606628.30
# 18     -2874166.13          -2874166.13          -2874166.13
# 19     -2874166.13          -2874166.13          -2874166.13
# 20     15426321.15          15426321.15          15426321.15
# 21     -2600000.00          -2600000.00          -2600000.00
# 22      2043636.60           2043636.60           2043636.60
#
#     Var.val.in rep.cur.  Purchase order text
# 0            4000000.00                 None
# 1             205792.00                 None
# 2            2600000.00                 None
# 3            -750000.00                 None
# 4              15000.00                 None
# 5             -15000.00                 None
# 6           45538930.43                 None
# 7           -2293539.80                 None
# 8              15000.00                 None
# 9             -15000.00                 None
# 10           -205792.00                 None
# 11            -15000.00                 None
# 12             15000.00                 None
# 13           -637795.50                 None
# 14          -1247186.55                 None
# 15          -2756927.23                 None
# 16          -2429451.31                 None
# 17          -2606628.30                 None
# 18          -2874166.13                 None
# 19          -2874166.13                 None
# 20          15426321.15                 None
# 21          -2600000.00                 None
# 22           2043636.60                 None
#
# [23 rows x 27 columns]

# %% [markdown]
# ### Logic 2
# - For each Projects in Transaction without any filter
#     - Pick the SB transaction for that project/wbs code
#     - Perform sub-total and get rid of the records which nullify each other i.e. amount = 0
#         - Of the remaining transactions,
#             - Identify the reference document numbers
#             - Prepare a dataset of these document numbers. All the entries will be SB
#             - Exclude the original project/WBS code
#     - Of the remaining transaction, get their corresponding ref. document numbers
#         - For each document numbers,
#             - Filter all corresponding SB transactions (filtered data with SB entries)
#             - Exclude the original project/wbs code from the filtered dataset
#             - If the value is less than 0, it's transferred to
#             - If the value is greater than 0, it's transferred from

# %%
final_data = final_data_bak.copy()

# %%
import pandas as pd
from itertools import combinations

def find_nullifying_groups(df):
    """
    Identify groups of values in the 'Value in Obj. Crcy' column that nullify each other,
    and return their corresponding 'Ref. document number'.

    Args:
    df (pd.DataFrame): The input DataFrame with columns 'Ref. document number' and 'Value in Obj. Crcy'.

    Returns:
    pd.DataFrame: A DataFrame containing the 'Ref. document number' and 'Value in Obj. Crcy'
                  of nullifying groups.
    """
    # Initialize a set to store indices of rows that nullify each other
    nullifying_indices = set()

    # Extract 'Value in Obj. Crcy' and their indices
    values = df['Value in Obj. Crcy'].tolist()
    index_map = df.index.tolist()  # Map positional indices to actual DataFrame indices

    n = len(values)

    # Check all combinations of rows to find nullifying groups
    for r in range(2, n + 1):  # At least 2 elements in the combination
        for combo in combinations(range(n), r):
            subset = [values[i] for i in combo]
            if abs(sum(subset)) < 1e-9:  # Check for near-zero sum
                # Map positional indices to DataFrame indices
                nullifying_indices.update(index_map[i] for i in combo)

    # Convert the set of indices to a list and filter the DataFrame
    result = df.loc[list(nullifying_indices)]
    return result

# %%
project_breakup = pd.DataFrame()

# %%
# Step 1
for proj in final_data['Object'].unique():
    print(proj)
    data = final_data[final_data['Object'] == proj]

    # Step 2
    nullifying_groups = find_nullifying_groups(data)

    # Step 3
    data_non_null = data[~data['Ref. document number'].isin(nullifying_groups['Ref. document number'])]

    # Step 4.1 and 4.2
    data_sb = final_data[final_data['Ref. document number'].isin(data_non_null['Ref. document number'])]

    # Step 4.3
    data_proj = data_sb[data_sb['Object'] != proj]

    # Concatenate the final data
    project_breakup = pd.concat([project_breakup, data_proj], ignore_index=True)

    break
# Out:
# DO/2009-HATSREV

# %%
data
# Out:
#     Document Number Ref. document number Posting Date Document Date  \
# 290    1002070478.0         2406001521.0   2024-05-06    2024-05-01
#
#     Document type Project definition           Object  Fiscal Year  \
# 290            DR       DO/2009-HATS  DO/2009-HATSREV       2024.0
#
#      Cost Element         Cost element descr.  ... Vbl. value/TranCurr.  \
# 290      550508.0  Rev-Domestic (Indian fund)  ...               -501.0
#
#      Vbl. value/Obj. curr Var.val.in rep.cur. Purchase order text  \
# 290                -501.0              -501.0                None
#
#               WBS                     WBS Details          Sub WBS  \
# 290  DO/2009-HATS  HOSTEL ALUMNI TEAM STEWARDSHIP  DO/2009-HATSREV
#
#        SUB WBS Details         Project Id        Category
# 290  Hostels - Receipt  hostels_-_receipt  Infrastructure
#
# [1 rows x 33 columns]

# %%
nullifying_groups
# Out:
# Empty DataFrame
# Columns: [Document Number, Ref. document number, Posting Date, Document Date, Document type, Project definition, Object, Fiscal Year, Cost Element, Cost element descr., Dr/Cr indicator, Val/COArea Crcy, CO area currency, Offsetting acct no., Name of offsetting account, Purchasing Document, Offsetting account type, Exchange Rate Type, Value Type, Value in Obj. Crcy, Report currency, Val.in rep.cur., Vbl.Val./COCrcy, Vbl. value/TranCurr., Vbl. value/Obj. curr, Var.val.in rep.cur., Purchase order text, WBS, WBS Details, Sub WBS, SUB WBS Details, Project Id, Category]
# Index: []
#
# [0 rows x 33 columns]

# %%
data_non_null
# Out:
#     Document Number Ref. document number Posting Date Document Date  \
# 290    1002070478.0         2406001521.0   2024-05-06    2024-05-01
#
#     Document type Project definition           Object  Fiscal Year  \
# 290            DR       DO/2009-HATS  DO/2009-HATSREV       2024.0
#
#      Cost Element         Cost element descr.  ... Vbl. value/TranCurr.  \
# 290      550508.0  Rev-Domestic (Indian fund)  ...               -501.0
#
#      Vbl. value/Obj. curr Var.val.in rep.cur. Purchase order text  \
# 290                -501.0              -501.0                None
#
#               WBS                     WBS Details          Sub WBS  \
# 290  DO/2009-HATS  HOSTEL ALUMNI TEAM STEWARDSHIP  DO/2009-HATSREV
#
#        SUB WBS Details         Project Id        Category
# 290  Hostels - Receipt  hostels_-_receipt  Infrastructure
#
# [1 rows x 33 columns]

# %%
data_proj
# Out:
# Empty DataFrame
# Columns: [Document Number, Ref. document number, Posting Date, Document Date, Document type, Project definition, Object, Fiscal Year, Cost Element, Cost element descr., Dr/Cr indicator, Val/COArea Crcy, CO area currency, Offsetting acct no., Name of offsetting account, Purchasing Document, Offsetting account type, Exchange Rate Type, Value Type, Value in Obj. Crcy, Report currency, Val.in rep.cur., Vbl.Val./COCrcy, Vbl. value/TranCurr., Vbl. value/Obj. curr, Var.val.in rep.cur., Purchase order text, WBS, WBS Details, Sub WBS, SUB WBS Details, Project Id, Category]
# Index: []
#
# [0 rows x 33 columns]

# %%
data_sb
# Out:
#     Document Number Ref. document number Posting Date Document Date  \
# 290    1002070478.0         2406001521.0   2024-05-06    2024-05-01
#
#     Document type Project definition           Object  Fiscal Year  \
# 290            DR       DO/2009-HATS  DO/2009-HATSREV       2024.0
#
#      Cost Element         Cost element descr.  ... Vbl. value/TranCurr.  \
# 290      550508.0  Rev-Domestic (Indian fund)  ...               -501.0
#
#      Vbl. value/Obj. curr Var.val.in rep.cur. Purchase order text  \
# 290                -501.0              -501.0                None
#
#               WBS                     WBS Details          Sub WBS  \
# 290  DO/2009-HATS  HOSTEL ALUMNI TEAM STEWARDSHIP  DO/2009-HATSREV
#
#        SUB WBS Details         Project Id        Category
# 290  Hostels - Receipt  hostels_-_receipt  Infrastructure
#
# [1 rows x 33 columns]

# %%
project_breakup
# Out:
# Empty DataFrame
# Columns: [Document Number, Ref. document number, Posting Date, Document Date, Document type, Project definition, Object, Fiscal Year, Cost Element, Cost element descr., Dr/Cr indicator, Val/COArea Crcy, CO area currency, Offsetting acct no., Name of offsetting account, Purchasing Document, Offsetting account type, Exchange Rate Type, Value Type, Value in Obj. Crcy, Report currency, Val.in rep.cur., Vbl.Val./COCrcy, Vbl. value/TranCurr., Vbl. value/Obj. curr, Var.val.in rep.cur., Purchase order text, WBS, WBS Details, Sub WBS, SUB WBS Details, Project Id, Category]
# Index: []
#
# [0 rows x 33 columns]

# %%
final_data.head()
# Out:
#      Document Number Ref. document number Posting Date Document Date  \
# 1047    1002161674.0         2426004989.0   2024-08-23    2024-08-23
# 1048    1002161674.0         2426004989.0   2024-08-23    2024-08-23
# 1051    1002164961.0         2426005166.0   2024-08-28    2024-08-27
# 1052    1002164961.0         2426005166.0   2024-08-28    2024-08-27
# 1408    1002199703.0         2426007241.0   2024-10-14    2024-10-01
#
#      Document type Project definition           Object  Fiscal Year  \
# 1047            SB       DO/2000-POOL  DO/2000-POOL002       2024.0
# 1048            SB       DO/2000-POOL  DO/2000-POOL002       2024.0
# 1051            SB       DO/2000-POOL  DO/2000-POOL002       2024.0
# 1052            SB       DO/2000-POOL  DO/2000-POOL002       2024.0
# 1408            SB       DO/2000-POOL  DO/2000-POOL002       2024.0
#
#       Cost Element  Cost element descr.  ... Vbl. value/TranCurr.  \
# 1047      510508.0      EXP-SCHOLARSHIP  ...             38348.88
# 1048      510508.0      EXP-SCHOLARSHIP  ...             36109.74
# 1051      510508.0      EXP-SCHOLARSHIP  ...             38348.88
# 1052      510508.0      EXP-SCHOLARSHIP  ...             36109.74
# 1408      550511.0  Rev-IITBHF Donation  ...         -32196387.45
#
#       Vbl. value/Obj. curr Var.val.in rep.cur. Purchase order text  \
# 1047              38348.88            38348.88                None
# 1048              36109.74            36109.74                None
# 1051              38348.88            38348.88                None
# 1052              36109.74            36109.74                None
# 1408          -32196387.45        -32196387.45                None
#
#                WBS            WBS Details          Sub WBS  \
# 1047  DO/2000-POOL  Donation Pool Account  DO/2000-POOL002
# 1048  DO/2000-POOL  Donation Pool Account  DO/2000-POOL002
# 1051  DO/2000-POOL  Donation Pool Account  DO/2000-POOL002
# 1052  DO/2000-POOL  Donation Pool Account  DO/2000-POOL002
# 1408  DO/2000-POOL  Donation Pool Account  DO/2000-POOL002
#
#           SUB WBS Details           Project Id  Category
# 1047  IIT BHF SCHOLARSHIP  iit_bhf_scholarship       NaN
# 1048  IIT BHF SCHOLARSHIP  iit_bhf_scholarship       NaN
# 1051  IIT BHF SCHOLARSHIP  iit_bhf_scholarship       NaN
# 1052  IIT BHF SCHOLARSHIP  iit_bhf_scholarship       NaN
# 1408  IIT BHF SCHOLARSHIP  iit_bhf_scholarship       NaN
#
# [5 rows x 33 columns]
